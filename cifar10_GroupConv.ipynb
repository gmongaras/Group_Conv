# %% [markdown]
# # **CIFAR 10**
# A FFNN (Feed Forward Neural Network) and CNN (Convolutional Nerual Network) have been modeled

# %% [markdown]
# ## Import required packages

# %%
import torch
from torchvision import datasets,transforms
from torch.utils.data import DataLoader, SubsetRandomSampler
import torch.nn as nn
import torch.nn.functional as F
import numpy as np 
import matplotlib.pyplot as plt 
from Group_Conv import Group_Conv

# %%
device = torch.device("cuda:0")

# %% [markdown]
# ## Defining our Transforms

# %%
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# Normalize the test set same as training set without augmentation
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

# %% [markdown]
# ## Gathering the train and test data

# %%
train_data=datasets.CIFAR10('data/CIFAR10',train=True,download=True,transform=transform_train)
test_data=datasets.CIFAR10('data/CIFAR10',train=False,download=True,transform=transform_test)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Defining our Train, Valid and Test Dataloaders

# %%
num_workers=0
batch_size=50
valid_size=0.2
train_length = len(train_data)
indices=list(range(len(train_data)))
split = int(np.floor(valid_size * train_length))

np.random.shuffle(indices)

train_idx=indices[split:]
valid_idx=indices[:split]

train_sampler=SubsetRandomSampler(train_idx)
validation_sampler=SubsetRandomSampler(valid_idx)

train_loader=DataLoader(train_data,num_workers=num_workers,batch_size=batch_size,sampler=train_sampler)
valid_loader=DataLoader(train_data,num_workers=num_workers,batch_size=batch_size,sampler=validation_sampler)
test_loader=DataLoader(test_data,shuffle=True,num_workers=num_workers,batch_size=batch_size)

# %% [markdown]
# ## Defining our Neural Net Architecture

# %%
class FNet(nn.Module):
    def __init__(self):
        super(FNet,self).__init__()
        self.fc1=nn.Linear(3*32*32,2048)
        self.fc2=nn.Linear(2048,1024)
        self.fc3=nn.Linear(1024,512)
        self.fc4=nn.Linear(512,256)
        self.out=nn.Linear(256,10)
        self.dropout=nn.Dropout(0.25)

    def forward(self,x):
        x=x.view(-1,32*32*3)
        x=self.dropout(F.relu(self.fc1(x)))
        x=self.dropout(F.relu(self.fc2(x)))
        x=self.dropout(F.relu(self.fc3(x)))
        x=self.dropout(F.relu(self.fc4(x)))
        x=self.out(x)
        return x

class convNet(nn.Module):
    def __init__(self):
        super(convNet,self).__init__()
        self.conv1=nn.Conv2d(3,16,3,groups=1,padding=1,device=device)
        self.conv2=nn.Conv2d(16,32,3,groups=2,padding=1,device=device)
        self.conv3=nn.Conv2d(32,64,3,groups=4,padding=1,device=device)
        self.conv4=nn.Conv2d(64,128,3,groups=4,padding=1,device=device)
        self.conv5=nn.Conv2d(128,256,3,groups=4,padding=1,device=device)
        self.b1=nn.BatchNorm2d(16)
        self.b2=nn.BatchNorm2d(64)
        self.b3=nn.BatchNorm2d(256)
        self.pool=nn.MaxPool2d(kernel_size=2,stride=2)  

        self.dropout=nn.Dropout(0.1)
        self.fc1=nn.Linear(256,128)
        self.fc2=nn.Linear(128,64)
        self.out=nn.Linear(64,10)


    def forward(self,x):
        x=self.pool(F.relu(self.b1(self.conv1(x))))
        x=self.pool(F.relu(self.conv2(x)))
        x=self.pool(F.relu(self.b2(self.conv3(x))))
        x=self.pool(F.relu(self.conv4(x)))
        x=self.pool(F.relu(self.b3(self.conv5(x))))
        x=x.view(-1,256)
        x = self.dropout(x)
        x=self.dropout(F.relu(self.fc1(x)))
        x=self.dropout(F.relu(self.fc2(x)))
        x=self.out(x)   
        return x

# %%
def weight_init_normal(m):
    classname=m.__class__.__name__
    if classname.find('Linear')!=-1:
        n = m.in_features
        y = (1.0/np.sqrt(n))
        m.weight.data.normal_(0, y)
        m.bias.data.fill_(0)

model_1=FNet()
model_2=convNet()
model_1.apply(weight_init_normal),model_2.apply(weight_init_normal)
use_cuda=True
if use_cuda and torch.cuda.is_available():
    model_1.cuda()
    model_2.cuda()
print(model_1,'\n\n\n\n',model_2,'\n','On GPU : ',use_cuda and torch.cuda.is_available())
# Out:
# FNet(
#   (fc1): Linear(in_features=3072, out_features=2048, bias=True)
#   (fc2): Linear(in_features=2048, out_features=1024, bias=True)
#   (fc3): Linear(in_features=1024, out_features=512, bias=True)
#   (fc4): Linear(in_features=512, out_features=256, bias=True)
#   (out): Linear(in_features=256, out_features=10, bias=True)
#   (dropout): Dropout(p=0.25, inplace=False)
# )
#
#
#
#  convNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4)
#   (conv4): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4)
#   (conv5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=4)
#   (b1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (b2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (b3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (fc1): Linear(in_features=256, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (out): Linear(in_features=64, out_features=10, bias=True)
# )
#  On GPU :  True

# %% [markdown]
# ## Defining our Loss Function

# %%
criterion=nn.CrossEntropyLoss()

# %% [markdown]
# ## Training and Validation Phase

# %%
def trainNet(model,lr,trainer,validater):
    optimizer=torch.optim.SGD(model.parameters(),lr=lr,momentum=0.9)


    # Number of epochs to train for
    loss_keeper={'train':[],'valid':[]}
    acc_keeper={'train':[],'valid':[]}
    train_class_correct = list(0. for i in range(10))
    valid_class_correct = list(0. for i in range(10))
    class_total = list(0. for i in range(10))
    epochs=50

    # minimum validation loss ----- set initial minimum to infinity
    valid_loss_min = np.Inf 

    for epoch in range(epochs):
        train_loss=0.0
        valid_loss=0.0
        train_correct=0.0
        valid_correct=0.0
        """
        TRAINING PHASE
        """
        model.train() # TURN ON DROPOUT for training
        for images,labels in trainer:
            if use_cuda and torch.cuda.is_available():
                images,labels=images.cuda(),labels.cuda()
            optimizer.zero_grad()
            output=model(images)
            loss=criterion(output,labels)
            loss.backward()
            optimizer.step()
            train_loss+=loss.item()
            _, pred = torch.max(output, 1)
            train_correct=np.squeeze(pred.eq(labels.data.view_as(pred)))
            for idx in range(batch_size):
                label = labels[idx]
                train_class_correct[label] += train_correct[idx].item()
                class_total[label] += 1

        """
        VALIDATION PHASE
        """
        model.eval() # TURN OFF DROPOUT for validation
        for images,labels in validater:
            if use_cuda and torch.cuda.is_available():
                images,labels=images.cuda(),labels.cuda()
            output=model(images)
            loss=criterion(output,labels)
            valid_loss+=loss.item()
            _, pred = torch.max(output, 1)
            valid_correct=np.squeeze(pred.eq(labels.data.view_as(pred)))
            for idx in range(batch_size):
                label = labels[idx]
                valid_class_correct[label] += valid_correct[idx].item()
                class_total[label] += 1

        # Calculating loss over entire batch size for every epoch
        train_loss = train_loss/len(trainer)
        valid_loss = valid_loss/len(validater)

        # Calculating loss over entire batch size for every epoch
        train_acc=float(100. * np.sum(train_class_correct) / np.sum(class_total))
        valid_acc=float(100. * np.sum(valid_class_correct) / np.sum(class_total))

        # saving loss values
        loss_keeper['train'].append(train_loss)
        loss_keeper['valid'].append(valid_loss)

        # saving acc values
        acc_keeper['train'].append(train_acc)
        acc_keeper['valid'].append(valid_acc)

        print(f"Epoch : {epoch+1}")
        print(f"Training Loss : {train_loss}\tValidation Loss : {valid_loss}")

        if valid_loss<=valid_loss_min:
            print(f"Validation loss decreased from : {valid_loss_min} ----> {valid_loss} ----> Saving Model.......")
            z=type(model).__name__
            torch.save(model.state_dict(), z+'_model.pth')
            valid_loss_min=valid_loss

        print(f"Training Accuracy : {train_acc}\tValidation Accuracy : {valid_acc}\n\n")

    return(loss_keeper,acc_keeper)

# %%
m2_loss,m2_acc=trainNet(model_2,0.01,train_loader,valid_loader)
# Out:
# Epoch : 1
# Training Loss : 1.5917558109760284	Validation Loss : 1.3346760120987893
# Validation loss decreased from : inf ----> 1.3346760120987893 ----> Saving Model.......
# Training Accuracy : 33.032	Validation Accuracy : 10.4
#
#
# Epoch : 2
# Training Loss : 1.2784927926957608	Validation Loss : 1.2264538499712945
# Validation loss decreased from : 1.3346760120987893 ----> 1.2264538499712945 ----> Saving Model.......
# Training Accuracy : 38.094	Validation Accuracy : 10.687
#
#
# Epoch : 3
# Training Loss : 1.1595665879547596	Validation Loss : 1.1892876389622689
# Validation loss decreased from : 1.2264538499712945 ----> 1.1892876389622689 ----> Saving Model.......
# Training Accuracy : 41.054	Validation Accuracy : 11.021333333333333
#
#
# Epoch : 4
# Training Loss : 1.0848068106919526	Validation Loss : 1.0687439540028572
# Validation loss decreased from : 1.1892876389622689 ----> 1.0687439540028572 ----> Saving Model.......
# Training Accuracy : 43.157	Validation Accuracy : 11.361
#
#
# Epoch : 5
# Training Loss : 1.0363519444316625	Validation Loss : 0.9746519094705581
# Validation loss decreased from : 1.0687439540028572 ----> 0.9746519094705581 ----> Saving Model.......
# Training Accuracy : 44.656	Validation Accuracy : 11.736
#
#
# Epoch : 6
# Training Loss : 0.9908104719221592	Validation Loss : 0.9587017685174942
# Validation loss decreased from : 0.9746519094705581 ----> 0.9587017685174942 ----> Saving Model.......
# Training Accuracy : 45.910666666666664	Validation Accuracy : 11.988333333333333
#
#
# Epoch : 7
# Training Loss : 0.9556457666307687	Validation Loss : 0.9493932500481606
# Validation loss decreased from : 0.9587017685174942 ----> 0.9493932500481606 ----> Saving Model.......
# Training Accuracy : 46.930285714285716	Validation Accuracy : 12.168285714285714
#
#
# Epoch : 8
# Training Loss : 0.9295359240844846	Validation Loss : 0.9500427815318108
# Training Accuracy : 47.827	Validation Accuracy : 12.3215
#
#
# Epoch : 9
# Training Loss : 0.891166898496449	Validation Loss : 0.8631895944476128
# Validation loss decreased from : 0.9493932500481606 ----> 0.8631895944476128 ----> Saving Model.......
# Training Accuracy : 48.626222222222225	Validation Accuracy : 12.505555555555556
#
#
# Epoch : 10
# Training Loss : 0.8758950121700764	Validation Loss : 0.8968124172091484
# Training Accuracy : 49.3136	Validation Accuracy : 12.6174
#
#
# Epoch : 11
# Training Loss : 0.8547163235768676	Validation Loss : 0.8372842954099178
# Validation loss decreased from : 0.8631895944476128 ----> 0.8372842954099178 ----> Saving Model.......
# Training Accuracy : 49.93145454545454	Validation Accuracy : 12.756727272727273
#
#
# Epoch : 12
# Training Loss : 0.8279912377893924	Validation Loss : 0.8767201572656631
# Training Accuracy : 50.51716666666667	Validation Accuracy : 12.8495
#
#
# Epoch : 13
# Training Loss : 0.8178610775992274	Validation Loss : 0.8263954530656338
# Validation loss decreased from : 0.8372842954099178 ----> 0.8263954530656338 ----> Saving Model.......
# Training Accuracy : 51.034	Validation Accuracy : 12.956461538461538
#
#
# Epoch : 14
# Training Loss : 0.802567479647696	Validation Loss : 0.8223574037849903
# Validation loss decreased from : 0.8263954530656338 ----> 0.8223574037849903 ----> Saving Model.......
# Training Accuracy : 51.51342857142857	Validation Accuracy : 13.052857142857142
#
#
# Epoch : 15
# Training Loss : 0.780627590790391	Validation Loss : 0.8030145919322967
# Validation loss decreased from : 0.8223574037849903 ----> 0.8030145919322967 ----> Saving Model.......
# Training Accuracy : 51.956	Validation Accuracy : 13.1468
#
#
# Epoch : 16
# Training Loss : 0.7717503858730197	Validation Loss : 0.7992091472446918
# Validation loss decreased from : 0.8030145919322967 ----> 0.7992091472446918 ----> Saving Model.......
# Training Accuracy : 52.375375	Validation Accuracy : 13.229125
#
#
# Epoch : 17
# Training Loss : 0.758520159162581	Validation Loss : 0.8117747977375984
# Training Accuracy : 52.76541176470588	Validation Accuracy : 13.297058823529412
#
#
# Epoch : 18
# Training Loss : 0.7396781646832824	Validation Loss : 0.7770869244635105
# Validation loss decreased from : 0.7992091472446918 ----> 0.7770869244635105 ----> Saving Model.......
# Training Accuracy : 53.13122222222222	Validation Accuracy : 13.368777777777778
#
#
# Epoch : 19
# Training Loss : 0.731980291120708	Validation Loss : 0.7498368997871876
# Validation loss decreased from : 0.7770869244635105 ----> 0.7498368997871876 ----> Saving Model.......
# Training Accuracy : 53.47231578947368	Validation Accuracy : 13.44221052631579
#
#
# Epoch : 20
# Training Loss : 0.7242587086930871	Validation Loss : 0.7732368333637715
# Training Accuracy : 53.7888	Validation Accuracy : 13.5021
#
#
# Epoch : 21
# Training Loss : 0.7055047030374407	Validation Loss : 0.7809216703474522
# Training Accuracy : 54.094095238095235	Validation Accuracy : 13.552761904761905
#
#
# Epoch : 22
# Training Loss : 0.6989611674845219	Validation Loss : 0.7434829875826836
# Validation loss decreased from : 0.7498368997871876 ----> 0.7434829875826836 ----> Saving Model.......
# Training Accuracy : 54.39481818181818	Validation Accuracy : 13.611090909090908
#
#
# Epoch : 23
# Training Loss : 0.6942874786630273	Validation Loss : 0.766338146328926
# Training Accuracy : 54.67252173913044	Validation Accuracy : 13.656608695652174
#
#
# Epoch : 24
# Training Loss : 0.687181259766221	Validation Loss : 0.7497545655071736
# Training Accuracy : 54.93216666666667	Validation Accuracy : 13.706
#
#
# Epoch : 25
# Training Loss : 0.6710345826297999	Validation Loss : 0.765228404700756
# Training Accuracy : 55.18064	Validation Accuracy : 13.74768
#
#
# Epoch : 26
# Training Loss : 0.6627212922275066	Validation Loss : 0.7491432066261768
# Training Accuracy : 55.428769230769234	Validation Accuracy : 13.793384615384616
#
#
# Epoch : 27
# Training Loss : 0.6626887744665146	Validation Loss : 0.7308583377301693
# Validation loss decreased from : 0.7434829875826836 ----> 0.7308583377301693 ----> Saving Model.......
# Training Accuracy : 55.65637037037037	Validation Accuracy : 13.836666666666666
#
#
# Epoch : 28
# Training Loss : 0.6486386572197079	Validation Loss : 0.7644094835221767
# Training Accuracy : 55.88364285714286	Validation Accuracy : 13.867214285714285
#
#
# Epoch : 29
# Training Loss : 0.646387320049107	Validation Loss : 0.750166023671627
# Training Accuracy : 56.094344827586205	Validation Accuracy : 13.898275862068965
#
#
# Epoch : 30
# Training Loss : 0.6367657452076674	Validation Loss : 0.7514994265139103
# Training Accuracy : 56.300466666666665	Validation Accuracy : 13.930666666666667
#
#
# Epoch : 31
# Training Loss : 0.641826280578971	Validation Loss : 0.7282232746481896
# Validation loss decreased from : 0.7308583377301693 ----> 0.7282232746481896 ----> Saving Model.......
# Training Accuracy : 56.488451612903226	Validation Accuracy : 13.96225806451613
#
#
# Epoch : 32
# Training Loss : 0.6275284237787128	Validation Loss : 0.7373936538398266
# Training Accuracy : 56.6794375	Validation Accuracy : 13.9898125
#
#
# Epoch : 33
# Training Loss : 0.6191536932066083	Validation Loss : 0.7074569855630398
# Validation loss decreased from : 0.7282232746481896 ----> 0.7074569855630398 ----> Saving Model.......
# Training Accuracy : 56.85575757575758	Validation Accuracy : 14.024363636363637
#
#
# Epoch : 34
# Training Loss : 0.6094053326174617	Validation Loss : 0.7229048778116703
# Training Accuracy : 57.03535294117647	Validation Accuracy : 14.055882352941177
#
#
# Epoch : 35
# Training Loss : 0.6055932867527009	Validation Loss : 0.7130007690191269
# Training Accuracy : 57.208285714285715	Validation Accuracy : 14.087314285714285
#
#
# Epoch : 36
# Training Loss : 0.5964628701284528	Validation Loss : 0.7023967465758324
# Validation loss decreased from : 0.7074569855630398 ----> 0.7023967465758324 ----> Saving Model.......
# Training Accuracy : 57.37616666666667	Validation Accuracy : 14.115666666666666
#
#
# Epoch : 37
# Training Loss : 0.6011293301358819	Validation Loss : 0.7241294866800309
# Training Accuracy : 57.535783783783785	Validation Accuracy : 14.140918918918919
#
#
# Epoch : 38
# Training Loss : 0.5919885480776429	Validation Loss : 0.7264916311204433
# Training Accuracy : 57.691947368421054	Validation Accuracy : 14.163842105263157
#
#
# Epoch : 39
# Training Loss : 0.5835854132845998	Validation Loss : 0.7193351349234581
# Training Accuracy : 57.84671794871795	Validation Accuracy : 14.188205128205128
#
#
# Epoch : 40
# Training Loss : 0.5811028849147261	Validation Loss : 0.7158182613551617
# Training Accuracy : 57.9941	Validation Accuracy : 14.21165
#
#
# Epoch : 41
# Training Loss : 0.5822558596730232	Validation Loss : 0.6925479678809643
# Validation loss decreased from : 0.7023967465758324 ----> 0.6925479678809643 ----> Saving Model.......
# Training Accuracy : 58.13639024390244	Validation Accuracy : 14.238829268292683
#
#
# Epoch : 42
# Training Loss : 0.5753462869860232	Validation Loss : 0.6834333582222462
# Validation loss decreased from : 0.6925479678809643 ----> 0.6834333582222462 ----> Saving Model.......
# Training Accuracy : 58.27247619047619	Validation Accuracy : 14.265095238095238
#
#
# Epoch : 43
# Training Loss : 0.566951708663255	Validation Loss : 0.7017473061382771
# Training Accuracy : 58.40846511627907	Validation Accuracy : 14.288
#
#
# Epoch : 44
# Training Loss : 0.5643225212767721	Validation Loss : 0.7050067959725856
# Training Accuracy : 58.54218181818182	Validation Accuracy : 14.308727272727273
#
#
# Epoch : 45
# Training Loss : 0.5564929405972362	Validation Loss : 0.6903527553379536
# Training Accuracy : 58.67462222222222	Validation Accuracy : 14.331333333333333
#
#
# Epoch : 46
# Training Loss : 0.5551334654912352	Validation Loss : 0.7133484837412835
# Training Accuracy : 58.800695652173914	Validation Accuracy : 14.347434782608696
#
#
# Epoch : 47
# Training Loss : 0.5470481754094362	Validation Loss : 0.713889449685812
# Training Accuracy : 58.92812765957447	Validation Accuracy : 14.364
#
#
# Epoch : 48
# Training Loss : 0.5443460940383374	Validation Loss : 0.7176694768667221
# Training Accuracy : 59.048833333333334	Validation Accuracy : 14.382166666666667
#
#
# Epoch : 49
# Training Loss : 0.5382947906665504	Validation Loss : 0.7251570743322372
# Training Accuracy : 59.170040816326534	Validation Accuracy : 14.396938775510204
#
#
# Epoch : 50
# Training Loss : 0.5343531284481287	Validation Loss : 0.7022714617848397
# Training Accuracy : 59.2872	Validation Accuracy : 14.4152

# %%
# Number of model parameters
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
count_parameters(model_2)
# Out:
# 142474

# %% [markdown]
# ## Let's make the model size comparable to the normal CIRFAR10 without grouping

# %%
class FNet(nn.Module):
    def __init__(self):
        super(FNet,self).__init__()
        self.fc1=nn.Linear(3*32*32,2048)
        self.fc2=nn.Linear(2048,1024)
        self.fc3=nn.Linear(1024,512)
        self.fc4=nn.Linear(512,256)
        self.out=nn.Linear(256,10)
        self.dropout=nn.Dropout(0.25)

    def forward(self,x):
        x=x.view(-1,32*32*3)
        x=self.dropout(F.relu(self.fc1(x)))
        x=self.dropout(F.relu(self.fc2(x)))
        x=self.dropout(F.relu(self.fc3(x)))
        x=self.dropout(F.relu(self.fc4(x)))
        x=self.out(x)
        return x

class convNet(nn.Module):
    def __init__(self):
        super(convNet,self).__init__()
        self.conv1=Group_Conv(3,16,3,sub_size=3,padding=1,device=device)
        self.conv2=Group_Conv(16,128,3,sub_size=8,padding=1,device=device)
        self.conv3=Group_Conv(128,256,3,sub_size=16,padding=1,device=device)
        self.conv4=Group_Conv(256,256,3,sub_size=32,padding=1,device=device)
        self.conv5=Group_Conv(256,256,3,sub_size=32,padding=1,device=device)
        self.b1=nn.BatchNorm2d(16)
        self.b2=nn.BatchNorm2d(256)
        self.b3=nn.BatchNorm2d(256)
        self.pool=nn.MaxPool2d(kernel_size=2,stride=2)  

        self.dropout=nn.Dropout(0.1)
        self.fc1=nn.Linear(256,128)
        self.fc2=nn.Linear(128,64)
        self.out=nn.Linear(64,10)


    def forward(self,x):
        x=self.pool(F.relu(self.b1(self.conv1(x))))
        x=self.pool(F.relu(self.conv2(x)))
        x=self.pool(F.relu(self.b2(self.conv3(x))))
        x=self.pool(F.relu(self.conv4(x)))
        x=self.pool(F.relu(self.b3(self.conv5(x))))
        x=x.view(-1,256)
        x = self.dropout(x)
        x=self.dropout(F.relu(self.fc1(x)))
        x=self.dropout(F.relu(self.fc2(x)))
        x=self.out(x)   
        return x

# %%
def weight_init_normal(m):
    classname=m.__class__.__name__
    if classname.find('Linear')!=-1:
        n = m.in_features
        y = (1.0/np.sqrt(n))
        m.weight.data.normal_(0, y)
        m.bias.data.fill_(0)

model_2=convNet()
use_cuda=True
if use_cuda and torch.cuda.is_available():
    model_2.cuda()
print(model_2,'\n','On GPU : ',use_cuda and torch.cuda.is_available())
# Out:
# convNet(
#   (conv1): Group_Conv()
#   (conv2): Group_Conv()
#   (conv3): Group_Conv()
#   (conv4): Group_Conv()
#   (conv5): Group_Conv()
#   (b1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (b2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (b3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (fc1): Linear(in_features=256, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (out): Linear(in_features=64, out_features=10, bias=True)
# )
#  On GPU :  True

# %%
# Number of model parameters
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
count_parameters(model_2)
# Out:
# 237738

# %%
criterion=nn.CrossEntropyLoss()

# %%
def trainNet(model,lr,trainer,validater):
    optimizer=torch.optim.SGD(model.parameters(),lr=lr,momentum=0.9)


    # Number of epochs to train for
    loss_keeper={'train':[],'valid':[]}
    acc_keeper={'train':[],'valid':[]}
    train_class_correct = list(0. for i in range(10))
    valid_class_correct = list(0. for i in range(10))
    class_total = list(0. for i in range(10))
    epochs=50

    # minimum validation loss ----- set initial minimum to infinity
    valid_loss_min = np.Inf 

    for epoch in range(epochs):
        train_loss=0.0
        valid_loss=0.0
        train_correct=0.0
        valid_correct=0.0
        """
        TRAINING PHASE
        """
        model.train() # TURN ON DROPOUT for training
        for images,labels in trainer:
            if use_cuda and torch.cuda.is_available():
                images,labels=images.cuda(),labels.cuda()
            optimizer.zero_grad()
            output=model(images)
            loss=criterion(output,labels)
            loss.backward()
            optimizer.step()
            train_loss+=loss.item()
            _, pred = torch.max(output, 1)
            train_correct=np.squeeze(pred.eq(labels.data.view_as(pred)))
            for idx in range(batch_size):
                label = labels[idx]
                train_class_correct[label] += train_correct[idx].item()
                class_total[label] += 1

        """
        VALIDATION PHASE
        """
        model.eval() # TURN OFF DROPOUT for validation
        for images,labels in validater:
            if use_cuda and torch.cuda.is_available():
                images,labels=images.cuda(),labels.cuda()
            output=model(images)
            loss=criterion(output,labels)
            valid_loss+=loss.item()
            _, pred = torch.max(output, 1)
            valid_correct=np.squeeze(pred.eq(labels.data.view_as(pred)))
            for idx in range(batch_size):
                label = labels[idx]
                valid_class_correct[label] += valid_correct[idx].item()
                class_total[label] += 1

        # Calculating loss over entire batch size for every epoch
        train_loss = train_loss/len(trainer)
        valid_loss = valid_loss/len(validater)

        # Calculating loss over entire batch size for every epoch
        train_acc=float(100. * np.sum(train_class_correct) / np.sum(class_total))
        valid_acc=float(100. * np.sum(valid_class_correct) / np.sum(class_total))

        # saving loss values
        loss_keeper['train'].append(train_loss)
        loss_keeper['valid'].append(valid_loss)

        # saving acc values
        acc_keeper['train'].append(train_acc)
        acc_keeper['valid'].append(valid_acc)

        print(f"Epoch : {epoch+1}")
        print(f"Training Loss : {train_loss}\tValidation Loss : {valid_loss}")

        if valid_loss<=valid_loss_min:
            print(f"Validation loss decreased from : {valid_loss_min} ----> {valid_loss} ----> Saving Model.......")
            z=type(model).__name__
            torch.save(model.state_dict(), z+'_model.pth')
            valid_loss_min=valid_loss

        print(f"Training Accuracy : {train_acc}\tValidation Accuracy : {valid_acc}\n\n")

    return(loss_keeper,acc_keeper)

# %%
m2_loss,m2_acc=trainNet(model_2,0.01,train_loader,valid_loader)
# Out:
# Epoch : 1
# Training Loss : 1.5613998767733575	Validation Loss : 1.342634438574314
# Validation loss decreased from : inf ----> 1.342634438574314 ----> Saving Model.......
# Training Accuracy : 33.534	Validation Accuracy : 9.962
#
#
# Epoch : 2
# Training Loss : 1.2167015182971954	Validation Loss : 1.121455855667591
# Validation loss decreased from : 1.342634438574314 ----> 1.121455855667591 ----> Saving Model.......
# Training Accuracy : 39.403	Validation Accuracy : 10.93
#
#
# Epoch : 3
# Training Loss : 1.0761341550946235	Validation Loss : 1.1364030435681343
# Training Accuracy : 42.82333333333333	Validation Accuracy : 11.376
#
#
# Epoch : 4
# Training Loss : 0.9914147022366524	Validation Loss : 0.9479898807406425
# Validation loss decreased from : 1.121455855667591 ----> 0.9479898807406425 ----> Saving Model.......
# Training Accuracy : 45.2035	Validation Accuracy : 11.8605
#
#
# Epoch : 5
# Training Loss : 0.9303539231419563	Validation Loss : 0.9100028432905674
# Validation loss decreased from : 0.9479898807406425 ----> 0.9100028432905674 ----> Saving Model.......
# Training Accuracy : 47.0152	Validation Accuracy : 12.2188
#
#
# Epoch : 6
# Training Loss : 0.8677223640680313	Validation Loss : 0.8676092293858528
# Validation loss decreased from : 0.9100028432905674 ----> 0.8676092293858528 ----> Saving Model.......
# Training Accuracy : 48.504333333333335	Validation Accuracy : 12.505
#
#
# Epoch : 7
# Training Loss : 0.823496648594737	Validation Loss : 0.8761551359295845
# Training Accuracy : 49.708285714285715	Validation Accuracy : 12.704571428571429
#
#
# Epoch : 8
# Training Loss : 0.7959180300310255	Validation Loss : 0.8327151529490948
# Validation loss decreased from : 0.8676092293858528 ----> 0.8327151529490948 ----> Saving Model.......
# Training Accuracy : 50.7275	Validation Accuracy : 12.90025
#
#
# Epoch : 9
# Training Loss : 0.7654570339247584	Validation Loss : 0.8059381444752216
# Validation loss decreased from : 0.8327151529490948 ----> 0.8059381444752216 ----> Saving Model.......
# Training Accuracy : 51.641777777777776	Validation Accuracy : 13.076666666666666
#
#
# Epoch : 10
# Training Loss : 0.7313206234201789	Validation Loss : 0.8454394249618054
# Training Accuracy : 52.4646	Validation Accuracy : 13.1926
#
#
# Epoch : 11
# Training Loss : 0.7109978367015719	Validation Loss : 0.7711369894444943
# Validation loss decreased from : 0.8059381444752216 ----> 0.7711369894444943 ----> Saving Model.......
# Training Accuracy : 53.18654545454545	Validation Accuracy : 13.33909090909091
#
#
# Epoch : 12
# Training Loss : 0.6897418918460607	Validation Loss : 0.7320766651630402
# Validation loss decreased from : 0.7711369894444943 ----> 0.7320766651630402 ----> Saving Model.......
# Training Accuracy : 53.846333333333334	Validation Accuracy : 13.4805
#
#
# Epoch : 13
# Training Loss : 0.6735372621938587	Validation Loss : 0.7292885246872902
# Validation loss decreased from : 0.7320766651630402 ----> 0.7292885246872902 ----> Saving Model.......
# Training Accuracy : 54.440615384615384	Validation Accuracy : 13.597692307692308
#
#
# Epoch : 14
# Training Loss : 0.6537600126489997	Validation Loss : 0.7201443713903427
# Validation loss decreased from : 0.7292885246872902 ----> 0.7201443713903427 ----> Saving Model.......
# Training Accuracy : 54.97742857142857	Validation Accuracy : 13.695714285714285
#
#
# Epoch : 15
# Training Loss : 0.6346494350209833	Validation Loss : 0.8233983659744263
# Training Accuracy : 55.48733333333333	Validation Accuracy : 13.756133333333333
#
#
# Epoch : 16
# Training Loss : 0.619528461676091	Validation Loss : 0.7378957667946815
# Training Accuracy : 55.942125	Validation Accuracy : 13.833875
#
#
# Epoch : 17
# Training Loss : 0.6040838485956193	Validation Loss : 0.7688519965112209
# Training Accuracy : 56.37117647058824	Validation Accuracy : 13.892588235294118
#
#
# Epoch : 18
# Training Loss : 0.5905653404630721	Validation Loss : 0.6997954736649991
# Validation loss decreased from : 0.7201443713903427 ----> 0.6997954736649991 ----> Saving Model.......
# Training Accuracy : 56.788111111111114	Validation Accuracy : 13.962222222222222
#
#
# Epoch : 19
# Training Loss : 0.578311916552484	Validation Loss : 0.6787425240874291
# Validation loss decreased from : 0.6997954736649991 ----> 0.6787425240874291 ----> Saving Model.......
# Training Accuracy : 57.16747368421053	Validation Accuracy : 14.038736842105264
#
#
# Epoch : 20
# Training Loss : 0.5650101508013904	Validation Loss : 0.7053458595275879
# Training Accuracy : 57.5311	Validation Accuracy : 14.0981
#
#
# Epoch : 21
# Training Loss : 0.5586336267367006	Validation Loss : 0.6845876318216324
# Training Accuracy : 57.86961904761905	Validation Accuracy : 14.154857142857143
#
#
# Epoch : 22
# Training Loss : 0.5430998683534562	Validation Loss : 0.6757857026159764
# Validation loss decreased from : 0.6787425240874291 ----> 0.6757857026159764 ----> Saving Model.......
# Training Accuracy : 58.18490909090909	Validation Accuracy : 14.212636363636364
#
#
# Epoch : 23
# Training Loss : 0.5420642071776092	Validation Loss : 0.732197977155447
# Training Accuracy : 58.48660869565217	Validation Accuracy : 14.25095652173913
#
#
# Epoch : 24
# Training Loss : 0.5338042345270515	Validation Loss : 0.6613777543604374
# Validation loss decreased from : 0.6757857026159764 ----> 0.6613777543604374 ----> Saving Model.......
# Training Accuracy : 58.76716666666667	Validation Accuracy : 14.306416666666667
#
#
# Epoch : 25
# Training Loss : 0.5181370212137699	Validation Loss : 0.6572583916783333
# Validation loss decreased from : 0.6613777543604374 ----> 0.6572583916783333 ----> Saving Model.......
# Training Accuracy : 59.04768	Validation Accuracy : 14.35768
#
#
# Epoch : 26
# Training Loss : 0.5106781232543289	Validation Loss : 0.6703046394884586
# Training Accuracy : 59.30784615384616	Validation Accuracy : 14.403461538461539
#
#
# Epoch : 27
# Training Loss : 0.5033280186355114	Validation Loss : 0.6546340760588646
# Validation loss decreased from : 0.6572583916783333 ----> 0.6546340760588646 ----> Saving Model.......
# Training Accuracy : 59.559777777777775	Validation Accuracy : 14.448296296296297
#
#
# Epoch : 28
# Training Loss : 0.4929531637951732	Validation Loss : 0.6572872222959996
# Training Accuracy : 59.80592857142857	Validation Accuracy : 14.486928571428571
#
#
# Epoch : 29
# Training Loss : 0.4790639350283891	Validation Loss : 0.6474173091351986
# Validation loss decreased from : 0.6546340760588646 ----> 0.6474173091351986 ----> Saving Model.......
# Training Accuracy : 60.04558620689655	Validation Accuracy : 14.52455172413793
#
#
# Epoch : 30
# Training Loss : 0.47693134225904943	Validation Loss : 0.6618131943047046
# Training Accuracy : 60.26833333333333	Validation Accuracy : 14.5594
#
#
# Epoch : 31
# Training Loss : 0.4749803985096514	Validation Loss : 0.6327552642673254
# Validation loss decreased from : 0.6474173091351986 ----> 0.6327552642673254 ----> Saving Model.......
# Training Accuracy : 60.48135483870968	Validation Accuracy : 14.597612903225807
#
#
# Epoch : 32
# Training Loss : 0.4566878204606473	Validation Loss : 0.6455078712850809
# Training Accuracy : 60.6934375	Validation Accuracy : 14.633
#
#
# Epoch : 33
# Training Loss : 0.4554955076985061	Validation Loss : 0.656443962752819
# Training Accuracy : 60.89957575757576	Validation Accuracy : 14.664181818181818
#
#
# Epoch : 34
# Training Loss : 0.45029486425220966	Validation Loss : 0.6527524416893721
# Training Accuracy : 61.09417647058824	Validation Accuracy : 14.694941176470588
#
#
# Epoch : 35
# Training Loss : 0.4469480207748711	Validation Loss : 0.6449897293746472
# Training Accuracy : 61.279428571428575	Validation Accuracy : 14.723542857142856
#
#
# Epoch : 36
# Training Loss : 0.4382754188403487	Validation Loss : 0.6474898464232683
# Training Accuracy : 61.465	Validation Accuracy : 14.750222222222222
#
#
# Epoch : 37
# Training Loss : 0.42478793919086455	Validation Loss : 0.6481594866514206
# Training Accuracy : 61.64810810810811	Validation Accuracy : 14.776756756756757
#
#
# Epoch : 38
# Training Loss : 0.4244225735403597	Validation Loss : 0.691861175596714
# Training Accuracy : 61.823473684210526	Validation Accuracy : 14.796526315789473
#
#
# Epoch : 39
# Training Loss : 0.42139791425317524	Validation Loss : 0.6278557743132115
# Validation loss decreased from : 0.6327552642673254 ----> 0.6278557743132115 ----> Saving Model.......
# Training Accuracy : 61.98902564102564	Validation Accuracy : 14.822358974358975
#
#
# Epoch : 40
# Training Loss : 0.4116530509851873	Validation Loss : 0.6380173859745264
# Training Accuracy : 62.15375	Validation Accuracy : 14.84735
#
#
# Epoch : 41
# Training Loss : 0.40998446009121836	Validation Loss : 0.6329683375731111
# Training Accuracy : 62.31234146341463	Validation Accuracy : 14.870585365853659
#
#
# Epoch : 42
# Training Loss : 0.4030222173500806	Validation Loss : 0.6661800527572632
# Training Accuracy : 62.46890476190476	Validation Accuracy : 14.889238095238095
#
#
# Epoch : 43
# Training Loss : 0.3993089049868286	Validation Loss : 0.6495791522413492
# Training Accuracy : 62.61860465116279	Validation Accuracy : 14.91013953488372
#
#
# Epoch : 44
# Training Loss : 0.39305611727759243	Validation Loss : 0.6598827121406794
# Training Accuracy : 62.76481818181818	Validation Accuracy : 14.931090909090909
#
#
# Epoch : 45
# Training Loss : 0.3928423349559307	Validation Loss : 0.6368232929706573
# Training Accuracy : 62.907333333333334	Validation Accuracy : 14.95191111111111
#
#
# Epoch : 46
# Training Loss : 0.3860417391173542	Validation Loss : 0.6436813905835151
# Training Accuracy : 63.044347826086955	Validation Accuracy : 14.969695652173913
#
#
# Epoch : 47
# Training Loss : 0.3839386597648263	Validation Loss : 0.6373889066278935
# Training Accuracy : 63.1796170212766	Validation Accuracy : 14.988808510638298
#
#
# Epoch : 48
# Training Loss : 0.37684724025428296	Validation Loss : 0.6783771119266748
# Training Accuracy : 63.31429166666667	Validation Accuracy : 15.002416666666667
#
#
# Epoch : 49
# Training Loss : 0.37660363760776816	Validation Loss : 0.6413462886214256
# Training Accuracy : 63.44020408163265	Validation Accuracy : 15.018122448979591
#
#
# Epoch : 50
# Training Loss : 0.37210986282676456	Validation Loss : 0.6493725819885731
# Training Accuracy : 63.56492	Validation Accuracy : 15.03596

# %%
# Number of model parameters
count_parameters(model_2)
